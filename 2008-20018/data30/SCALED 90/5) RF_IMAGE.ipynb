# %% [markdown]
# ### Select the Right Threshold values using ROC Curve

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# roc curve and auc score
from sklearn.datasets import make_classification
from sklearn.model_selection import RandomizedSearchCV 
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from imblearn.over_sampling import SMOTE

import pandas as pd

futures=['Opt_ES',"Opt_6B","Opt_CL","Opt_RTY","Opt_YM","Opt_ZN","Opt_ZS","Opt_ZW","Opt_NQ","Opt_GC","Opt_FDAX",]

tttt=['R1 Buy','R1 Sell']
for  CON in futures:
    for RULE in tttt:
        fff= '../'+CON+'.csv'
        data = pd.read_csv(fff)
        data=data.drop(['I31', 'Entry Time','Entry Price', 'Exit Price'],axis=1)
        data.head(3)

        data=data[data['Entry Name']==RULE]
        data=data.drop(['Entry Name'],axis=1)
        data=data.apply(lambda x: pd.to_numeric(x, errors='coerce')).dropna()
        data.head()
        data=data.round(6)
        data=data.dropna()
        x1 = data.drop(["Profit"],axis=1)
        y1 = data.Profit
        data1 = pd.concat([x1,y1],axis=1)
        train_data=data1.iloc[:int(0.9*len(data1)),]
        data2=data1.iloc[int(0.9*len(data1)):,]
        data2.shape

        train=train_data.iloc[:int(0.9*len(train_data)),]
        test= train_data.iloc[int(0.9*len(train_data)):,]
        vali=data2
        print(vali.shape)
        X_train=train.drop(["Profit"],axis=1)
        y_train=train.Profit

        X_test2=test.drop(["Profit"],axis=1)
        y_test2=test.Profit

        X_test=vali.drop(["Profit"],axis=1)
        y_test=vali.Profit
        
        

        sm = SMOTE(sampling_strategy=0.9)
        X_train, y_train = sm.fit_resample(X_train,y_train)



        # validate== xtest , ytest
        ## test== x_test2, y_test2

        from sklearn.ensemble import RandomForestClassifier

        grid = { 'bootstrap': [True, False],
                'n_estimators':np.arange(400,1000,100),
                'criterion':['gini','entropy'],
                'max_depth': [5, 15, 20, 25,30],
                'min_samples_leaf': [1, 2, 4],
                'min_samples_split': [2, 5, 10]

               }

        rf = RandomForestClassifier(random_state = 42)
        rf_model = RandomizedSearchCV(rf,grid,cv=5)
        rf_model.fit(X_train,y_train)

        print("Hyperparameters:",rf_model.best_params_)
        print("Train Score:",rf_model.best_score_)
        print("Test Score:",rf_model.score(X_test,y_test))

        pred=[]
        for model in [rf_model]:
            pred.append(pd.Series(model.predict_proba(X_test2)[:,1]))
        final_prediction=pd.concat(pred,axis=1).mean(axis=1)
        print('Ensemble test roc-auc: {}'.format(roc_auc_score(y_test2,final_prediction)))
        pd.concat(pred,axis=1)
        fpr, tpr, thresholds = roc_curve(y_test2, final_prediction)
        print(thresholds)


        from sklearn.metrics import accuracy_score
        from sklearn.metrics import f1_score
        from sklearn.metrics import recall_score
        from sklearn.metrics import precision_score
        accuracy_ls = []
        recall_ls=[]
        precision_ls=[]
        precision_ls=[]
        for thres in thresholds:
            y_pred = np.where(final_prediction>thres,1,0)
            accuracy_ls.append(accuracy_score(y_test2, y_pred, normalize=True))
            recall_ls.append(recall_score(y_test2, y_pred))
            precision_ls.append(precision_score(y_test2, y_pred))

        accuracy_ls = pd.concat([pd.Series(thresholds), pd.Series(accuracy_ls),pd.Series(recall_ls),pd.Series(precision_ls)],
                                axis=1)
        accuracy_ls.columns = ['thresholds', 'accuracy','recall','precision']
        accuracy_ls.sort_values(by='precision', ascending=False, inplace=True)
        accuracy_ls.head()

        pred=[]
        for model in [rf_model]:
            pred.append(pd.Series(model.predict_proba(X_test)[:,1]))
        final_prediction=pd.concat(pred,axis=1).mean(axis=1)
        print('Ensemble test roc-auc: {}'.format(roc_auc_score(y_test,final_prediction)))
        csv_save=CON+' '+RULE+'.csv'
        accuracy_ls.to_csv(csv_save)


        for i in range(15):
            TS= accuracy_ls.iloc[i,0]
            pred = np.where(final_prediction>TS,1,0)

            import seaborn as sns
            from sklearn.metrics import classification_report
            from sklearn.metrics import confusion_matrix
            from sklearn.metrics import plot_confusion_matrix
            import matplotlib.pyplot as plt
            #pred=rf_cv.predict(x_test)
            cm=confusion_matrix(y_test,pred)
            fn = cm[0][1]
            #print(fn)
            tp = cm[1][1]
            try:
                recall= float(tp)/(float(tp)+float(fn))
            except: 
                recall= 'NONE'
            print("this is precision ---->", recall)
            print('FDAX BUY')
            print('Thresold values: ', TS)
            ttt="Precision: "+str(recall)+ ' thresold: '+str(TS)+"  "+ str(CON)
            ttsave=str(CON)+' '+str(i)+str(RULE)+"Precision"+str(recall)+'thresold'+str(TS)+'.png'
            sns.heatmap(confusion_matrix(y_test,pred),annot=True,fmt='2.0f',cmap="summer")
            plt.title(ttt, y=1.05, size=10)
            plt.xlabel("Predicted")
            plt.ylabel("Actual")

            plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
            plt.show()
# Out:
# (143, 49)
# Hyperparameters: {'n_estimators': 600, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 25, 'criterion': 'gini', 'bootstrap': True}
# Train Score: 0.4985380473185351
# Test Score: 0.5874125874125874
# Ensemble test roc-auc: 0.5665384615384614
# [1.6662963  0.6662963  0.66493827 0.66163265 0.65492063 0.61313475
#  0.58809524 0.58325397 0.58153846 0.58       0.57434005 0.56647434
#  0.55320513 0.54977954 0.54682612 0.54       0.53496599 0.53136379
#  0.52983114 0.52968201 0.52       0.50481982 0.50333333 0.49981982
#  0.49489899 0.49333333 0.48636991 0.47166667 0.46814815 0.46666667
#  0.46492063 0.46333333 0.46166667 0.46155067 0.45675439 0.45666667
#  0.45333333 0.45166667 0.44666667 0.44452381 0.435      0.42823232
#  0.4215338  0.41833333 0.41333333 0.40993827 0.40833333 0.40666667
#  0.40333333 0.40166667 0.39833333 0.39333333 0.39156566 0.38995062
#  0.38833333 0.38666667 0.38642857 0.38307529 0.37325397 0.365
#  0.35825397 0.35166667 0.34166667 0.33333333 0.32333333 0.3232967
#  0.31833333 0.30333333 0.28       0.24333333]
# C:\Users\mk16m\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mk16m\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Ensemble test roc-auc: 0.5005201831044528
# this is precision ----> 0.42857142857142855
# FDAX BUY
# Thresold values:  0.58
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.5384615384615384
# FDAX BUY
# Thresold values:  0.5497795414462081
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.5
# FDAX BUY
# Thresold values:  0.5832539682539682
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.5
# FDAX BUY
# Thresold values:  0.5532051282051281
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.5384615384615384
# FDAX BUY
# Thresold values:  0.5468261150614091
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.5
# FDAX BUY
# Thresold values:  0.5815384615384616
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.5
# FDAX BUY
# Thresold values:  0.5743400477400478
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.6
# FDAX BUY
# Thresold values:  0.5664743369535538
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.5217391304347826
# FDAX BUY
# Thresold values:  0.52
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.5
# FDAX BUY
# Thresold values:  0.54
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.5
# FDAX BUY
# Thresold values:  0.5313637905304572
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.47619047619047616
# FDAX BUY
# Thresold values:  0.5296820105820105
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.5
# FDAX BUY
# Thresold values:  0.5880952380952381
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.25
# FDAX BUY
# Thresold values:  0.6131347520750606
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.0
# FDAX BUY
# Thresold values:  0.6616326530612245
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# (118, 49)
# Hyperparameters: {'n_estimators': 700, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 15, 'criterion': 'entropy', 'bootstrap': False}
# Train Score: 0.650064850843061
# Test Score: 0.6016949152542372
# Ensemble test roc-auc: 0.5315895372233401
# [1.63633359 0.63633359 0.59158646 0.57993797 0.57690246 0.57495904
#  0.55418281 0.55189434 0.55143239 0.54791695 0.52863745 0.52526983
#  0.51855587 0.51263882 0.50730167 0.49414527 0.48243676 0.47382983
#  0.43074448 0.42510183 0.42130743 0.42103918 0.41428866 0.40625178
#  0.3821461  0.37085589 0.3641559  0.36187804 0.35594726 0.35322104
#  0.34435351 0.33928153 0.32539774 0.32185216 0.29216564 0.28371799
#  0.28322111 0.27386996 0.24713026 0.24638793 0.2309721  0.21750354
#  0.18567424 0.18074546 0.17456504 0.16635659 0.11302521]
# C:\Users\mk16m\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mk16m\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Ensemble test roc-auc: 0.5156641604010025
# this is precision ----> 0.391304347826087
# FDAX BUY
# Thresold values:  0.5286374458351041
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.4
# FDAX BUY
# Thresold values:  0.5479169496116074
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.4166666666666667
# FDAX BUY
# Thresold values:  0.5514323915028885
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.391304347826087
# FDAX BUY
# Thresold values:  0.5252698301820056
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.4166666666666667
# FDAX BUY
# Thresold values:  0.5185558651417564
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.4166666666666667
# FDAX BUY
# Thresold values:  0.47382983313531546
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.4166666666666667
# FDAX BUY
# Thresold values:  0.5541828130292871
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.4117647058823529
# FDAX BUY
# Thresold values:  0.48243676288760995
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.4
# FDAX BUY
# Thresold values:  0.5126388226273535
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.3333333333333333
# FDAX BUY
# Thresold values:  0.3218521563064888
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.34177215189873417
# FDAX BUY
# Thresold values:  0.3253977449729024
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.38461538461538464
# FDAX BUY
# Thresold values:  0.5073016724291087
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.34210526315789475
# FDAX BUY
# Thresold values:  0.3392815329630156
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.3402061855670103
# FDAX BUY
# Thresold values:  0.27386995689632676
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# this is precision ----> 0.35
# FDAX BUY
# Thresold values:  0.2471302615410939
# C:\Users\mk16m\AppData\Local\Temp/ipykernel_23204/2594737972.py:147: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(ttsave,dpi=100, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
# (144, 49)

# %% [markdown]
# CON='CL_buy'
# train1=pd.read_csv('CL_buy_test.csv')
# print(train1.shape)
# train1 = train1.sample(frac = 1)
# print(train1.tail(20))
# train=train1.iloc[:int(0.9*len(train1)),]
# test2= train1.iloc[int(0.9*len(train1)):,]
# test=pd.read_csv('CL_buy_train.csv')
# print(test.shape)
# X_train=train.drop(["Profit"],axis=1)
# y_train=train.Profit
#
# X_test=test.drop(["Profit"],axis=1)
# y_test=test.Profit
#
# X_test2=test2.drop(["Profit"],axis=1)
# y_test2=test2.Profit

# %% [markdown]
# #### Random Forests

# %% [markdown]
# #### No we will focus on selecting the best threshold for maximum accuracy

# %%
final_prediction

# %%
#### Calculate the ROc Curve

# %%
accuracy_ls

# %%
plot_roc_curve(fpr,tpr)

# %%
for i in range(15):
    TS= accuracy_ls.iloc[i,0]
    pred = np.where(final_prediction>TS,1,0)

    import seaborn as sns
    from sklearn.metrics import classification_report
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import plot_confusion_matrix
    import matplotlib.pyplot as plt
    #pred=rf_cv.predict(x_test)
    cm=confusion_matrix(y_test,pred)
    fn = cm[0][1]
    #print(fn)
    tp = cm[1][1]
    try:
        recall= float(tp)/(float(tp)+float(fn))
    except: 
        recall= 'NONE'
    print("this is precision ---->", recall)
    print('FDAX BUY')
    print('Thresold values: ', TS)
    ttt="Precision: "+str(recall)+ ' thresold: '+str(TS)+"  "+ str(CON)
    ttsave=str(i)+str(CON)+"Precision"+str(recall)+'thresold'+str(TS)+'.png'
    sns.heatmap(confusion_matrix(y_test,pred),annot=True,fmt='2.0f',cmap="summer")
    plt.title(ttt, y=1.05, size=10)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    
    plt.savefig(ttsave,dpi=300, facecolor='w', edgecolor='w', papertype=None, format=None, transparent=False)
    plt.show()
